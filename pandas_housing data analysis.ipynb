# %%
import pandas as pd 
df = pd.read_csv('D:/Python praactice/data/train.csv', index_col='Id') 
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.describe().round(2)
# Out:
#        MSSubClass  LotFrontage    LotArea  OverallQual  OverallCond  \
# count      1460.0      1201.00    1460.00      1460.00      1460.00
# mean         56.9        70.05   10516.83         6.10         5.58
# std          42.3        24.28    9981.26         1.38         1.11
# min          20.0        21.00    1300.00         1.00         1.00
# 25%          20.0        59.00    7553.50         5.00         5.00
# 50%          50.0        69.00    9478.50         6.00         5.00
# 75%          70.0        80.00   11601.50         7.00         6.00
# max         190.0       313.00  215245.00        10.00         9.00
#
#        YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  \
# count    1460.00       1460.00     1452.00     1460.00     1460.00  ...
# mean     1971.27       1984.87      103.69      443.64       46.55  ...
# std        30.20         20.65      181.07      456.10      161.32  ...
# ...

# %%
df['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
cate = []
for i in cate:
        print(i)

# %%
for col in df:
        print(df[col].unique())
# Out:
# [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
# [ 65.  80.  68.  60.  84.  85.  75.  nan  51.  50.  70.  91.  72.  66.
#  101.  57.  44. 110.  98.  47. 108. 112.  74. 115.  61.  48.  33.  52.
#  100.  24.  89.  63.  76.  81.  95.  69.  21.  32.  78. 121. 122.  40.
#  105.  73.  77.  64.  94.  34.  90.  55.  88.  82.  71. 120. 107.  92.
#  134.  62.  86. 141.  97.  54.  41.  79. 174.  99.  67.  83.  43. 103.
#   93.  30. 129. 140.  35.  37. 118.  87. 116. 150. 111.  49.  96.  59.
#   36.  56. 102.  58.  38. 109. 130.  53. 137.  45. 106. 104.  42.  39.
#  144. 114. 128. 149. 313. 168. 182. 138. 160. 152. 124. 153.  46.]
# [ 8450  9600 11250 ... 17217 13175  9717]
# ['Pave' 'Grvl']
# [nan 'Grvl' 'Pave']
# ['Reg' 'IR1' 'IR2' 'IR3']
# ['Lvl' 'Bnk' 'Low' 'HLS']
# ['AllPub' 'NoSeWa']
# ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# ['Gtl' 'Mod' 'Sev']
# ['CollgCr' 'Veenker' 'Crawfor' 'NoRidge' 'Mitchel' 'Somerst' 'NWAmes'
# ...

# %%
filt = (df['MSZoning']) == 'RL'
filt.head (10)
# Out:
# Id
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9     False
# 10     True
# Name: MSZoning, dtype: bool

# %%
filt2 = (df['MSZoning'] == 'RL') 
RL = df[filt2]
RL
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
filt3 = (df['MSZoning'] == 'RM') 
RM = df[filt3]
RM
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 24           120       RM         44.0     4224   Pave   NaN      Reg
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1429          30       RM         60.0     7200   Pave   NaN      Reg
# 1439          20       RM         90.0     7407   Pave   NaN      Reg
# 1442         120       RM          NaN     4426   Pave   NaN      Reg
# 1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1453         180       RM         35.0     3675   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
filt4 = (df['MSZoning'] == 'RH') 
RH = df[filt4]
RH
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 342           20       RH         60.0     8400   Pave   NaN      Reg
# 384           45       RH         60.0     9000   Pave   NaN      Reg
# 544          120       RH         34.0     4058   Pave   NaN      Reg
# 636          190       RH         60.0    10896   Pave  Pave      Reg
# 672           70       RH         54.0     6629   Pave   NaN      Reg
# 682           50       RH         55.0     4500   Pave  Pave      IR2
# 779           90       RH         60.0     8400   Pave   NaN      Reg
# 841           70       RH          NaN    12155   Pave   NaN      IR1
# 914           90       RH         82.0     6270   Pave   NaN      Reg
# 952           20       RH         60.0     7800   Pave   NaN      Reg
# 956           90       RH         82.0     7136   Pave   NaN      IR1
# 1031         190       RH          NaN     7082   Pave   NaN      Reg
# ...

# %%
filt5 = (df['LotFrontage'].ge(80))
filt5
# Out:
# Id
# 1       False
# 2        True
# 3       False
# 4       False
# 5        True
#         ...
# 1456    False
# 1457     True
# 1458    False
# 1459    False
# 1460    False
# Name: LotFrontage, Length: 1460, dtype: bool

# %%
filt4 = df['LotFrontage'] > 80
filt4
# Out:
# Id
# 1       False
# 2       False
# 3       False
# 4       False
# 5        True
#         ...
# 1456    False
# 1457     True
# 1458    False
# 1459    False
# 1460    False
# Name: LotFrontage, Length: 1460, dtype: bool

# %%
df2 = ['MSZoning', 'LandContour']
df.loc[filt4, df2 ]
# Out:
#      MSZoning LandContour
# Id
# 5          RL         Lvl
# 6          RL         Lvl
# 12         RL         Lvl
# 14         RL         Lvl
# 21         RL         Lvl
# ...       ...         ...
# 1438       RL         Lvl
# 1439       RM         Lvl
# 1443       FV         Lvl
# 1454       RL         Lvl
# 1457       RL         Lvl
#
# [284 rows x 2 columns]

# %%
LotFrontage = df.groupby('LotFrontage')['LotFrontage'].count()
LotFrontage
# Out:
# LotFrontage
# 21.0     23
# 24.0     19
# 30.0      6
# 32.0      5
# 33.0      1
#          ..
# 160.0     1
# 168.0     1
# 174.0     2
# 182.0     1
# 313.0     2
# Name: LotFrontage, Length: 110, dtype: int64

# %%
df.fillna(-1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave    -1      Reg
# 2             20       RL         80.0     9600   Pave    -1      Reg
# 3             60       RL         68.0    11250   Pave    -1      IR1
# 4             70       RL         60.0     9550   Pave    -1      IR1
# 5             60       RL         84.0    14260   Pave    -1      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave    -1      Reg
# 1457          20       RL         85.0    13175   Pave    -1      Reg
# 1458          70       RL         66.0     9042   Pave    -1      Reg
# 1459          20       RL         68.0     9717   Pave    -1      Reg
# 1460          20       RL         75.0     9937   Pave    -1      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df.loc[200,['LotConfig', 'Fence']] = ['Outside', 'Yes']
df.head(200)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1            60       RL         65.0     8450   Pave   NaN      Reg
# 2            20       RL         80.0     9600   Pave   NaN      Reg
# 3            60       RL         68.0    11250   Pave   NaN      IR1
# 4            70       RL         60.0     9550   Pave   NaN      IR1
# 5            60       RL         84.0    14260   Pave   NaN      IR1
# ..          ...      ...          ...      ...    ...   ...      ...
# 196         160       RL         24.0     2280   Pave   NaN      Reg
# 197          20       RL         79.0     9416   Pave   NaN      Reg
# 198          75       RL        174.0    25419   Pave   NaN      Reg
# 199          75       RM         92.0     5520   Pave   NaN      Reg
# 200          20       RL         76.0     9591   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                   ...
# ...

# %%
df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df
copy = df.copy()

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df2=df.copy()
df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df2.columns = df.iloc[0]
df2
# Out:
# 1     60  RL  65.0   8450  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN  \
# Id                                                              ...
# 1     60  RL  65.0   8450  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN
# 2     20  RL  80.0   9600  Pave  NaN  Reg  Lvl  AllPub     FR2  ...  0  NaN
# 3     60  RL  68.0  11250  Pave  NaN  IR1  Lvl  AllPub  Inside  ...  0  NaN
# 4     70  RL  60.0   9550  Pave  NaN  IR1  Lvl  AllPub  Corner  ...  0  NaN
# 5     60  RL  84.0  14260  Pave  NaN  IR1  Lvl  AllPub     FR2  ...  0  NaN
# ...   ..  ..   ...    ...   ...  ...  ...  ...     ...     ...  ... ..  ...
# 1456  60  RL  62.0   7917  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN
# 1457  20  RL  85.0  13175  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN
# 1458  70  RL  66.0   9042  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN
# 1459  20  RL  68.0   9717  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0  NaN
# ...

# %%
#5.Count all the values in Fence and MisFeature
fence_count = df['Fence'].value_counts()
fence_count
# Out:
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Yes        1
# Name: Fence, dtype: int64

# %%
MiscFeature_count = df['MiscFeature'].value_counts()
MiscFeature_count
# Out:
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: MiscFeature, dtype: int64

# %%
count = (df['Fence'].value_counts()) & (df['MiscFeature'].value_counts())
count
# Out:
# Gar2     False
# GdPrv    False
# GdWo     False
# MnPrv    False
# MnWw     False
# Othr     False
# Shed     False
# TenC     False
# Yes      False
# dtype: bool

# %%
# 6.Get the sum of the observations in LotFrontage
LotFrontage_sum = df['LotFrontage'].sum()
LotFrontage_sum
# Out:
# 84130.0

# %%
LotFrontage= df['LotFrontage'].value_counts().sum()
LotFrontage
# Out:
# 1201

# %%
df['LotFrontage'].value_counts().sum()
# Out:
# 1201

# %%
# 7.get the rows in MiscFeature with the string Shed
df['MiscFeature'].unique()
df[df['MiscFeature']== 'Shed']
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 52            50       RM         52.0     6240   Pave   NaN      Reg
# 85            80       RL          NaN     8530   Pave   NaN      IR1
# 96            60       RL          NaN     9765   Pave   NaN      IR2
# 99            30       RL         85.0    10625   Pave   NaN      Reg
# 100           20       RL         77.0     9320   Pave   NaN      IR1
# 107           30       RM         60.0    10800   Pave  Grvl      Reg
# 215           60       RL          NaN    10900   Pave   NaN      IR1
# 250           50       RL          NaN   159000   Pave   NaN      IR2
# ...

# %%
df[df['MiscFeature'].str.contains('Shed', na=False)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 52            50       RM         52.0     6240   Pave   NaN      Reg
# 85            80       RL          NaN     8530   Pave   NaN      IR1
# 96            60       RL          NaN     9765   Pave   NaN      IR2
# 99            30       RL         85.0    10625   Pave   NaN      Reg
# 100           20       RL         77.0     9320   Pave   NaN      IR1
# 107           30       RM         60.0    10800   Pave  Grvl      Reg
# 215           60       RL          NaN    10900   Pave   NaN      IR1
# 250           50       RL          NaN   159000   Pave   NaN      IR2
# ...

# %%
#8. Copy the dataframe, replace header with row 4 and rename the first three cols 
df3=df.copy()
df3
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# replace header with row 4
df3.columns = df.iloc[4]
df3.columns
# Out:
# Index([       60,      'RL',      84.0,     14260,    'Pave',       nan,
#            'IR1',     'Lvl',  'AllPub',     'FR2',     'Gtl', 'NoRidge',
#           'Norm',    'Norm',    '1Fam',  '2Story',         8,         5,
#             2000,      2000,   'Gable', 'CompShg', 'VinylSd', 'VinylSd',
#        'BrkFace',     350.0,      'Gd',      'TA',   'PConc',      'Gd',
#             'TA',      'Av',     'GLQ',       655,     'Unf',         0,
#              490,      1145,    'GasA',      'Ex',       'Y',   'SBrkr',
#             1145,      1053,         0,      2198,         1,         0,
#                2,         1,         4,         1,      'Gd',         9,
#            'Typ',         1,      'TA',  'Attchd',    2000.0,     'RFn',
#                3,       836,      'TA',      'TA',       'Y',       192,
#               84,         0,         0,         0,         0,       nan,
#              nan,       nan,         0,        12,      2008,      'WD',
# ...

# %%
#rename the first three cols
df4 = df3.rename(columns = {'5':'id','RL':'MS_Zoning', '84.0':'84_1'})
df4
# Out:
# 5     60 MS_Zoning  84.0  14260  Pave  NaN  IR1  Lvl  AllPub     FR2  ...  0  \
# Id                                                                    ...
# 1     60        RL  65.0   8450  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0
# 2     20        RL  80.0   9600  Pave  NaN  Reg  Lvl  AllPub     FR2  ...  0
# 3     60        RL  68.0  11250  Pave  NaN  IR1  Lvl  AllPub  Inside  ...  0
# 4     70        RL  60.0   9550  Pave  NaN  IR1  Lvl  AllPub  Corner  ...  0
# 5     60        RL  84.0  14260  Pave  NaN  IR1  Lvl  AllPub     FR2  ...  0
# ...   ..       ...   ...    ...   ...  ...  ...  ...     ...     ...  ... ..
# 1456  60        RL  62.0   7917  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0
# 1457  20        RL  85.0  13175  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0
# 1458  70        RL  66.0   9042  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0
# 1459  20        RL  68.0   9717  Pave  NaN  Reg  Lvl  AllPub  Inside  ...  0
# ...

# %%
# 9 Sort the dataframe using column  MoSold in descending order 
df.sort_values(by = 'MoSold', ascending=False)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1393          85       RL         68.0     7838   Pave   NaN      Reg
# 1178          50       RM          NaN     3950   Pave  Grvl      Reg
# 1119          80       RL         85.0    13825   Pave   NaN      Reg
# 650          180       RM         21.0     1936   Pave   NaN      Reg
# 191           70       RL         70.0    10570   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 730           30       RM         52.0     6240   Pave  Grvl      Reg
# 204          120       RM          NaN     4438   Pave   NaN      Reg
# 916          160       RM         21.0     2001   Pave   NaN      Reg
# 911           90       RL         80.0    11600   Pave   NaN      Reg
# 1058          60       RL          NaN    29959   Pave   NaN      IR2
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
# 10 Rmove the last 5 columns of the dataframe
df.drop(columns = ['MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'])
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... WoodDeckSF OpenPorchSF  \
# Id                                    ...
# ...

# %%
# 11 Drop all rows where PoolQC is nan
df[df.PoolQC == 'NaN']
# Out:
# Empty DataFrame
# Columns: [MSSubClass, MSZoning, LotFrontage, LotArea, Street, Alley, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinType2, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, Electrical, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, GarageCond, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, PoolQC, Fence, MiscFeature, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []
#
# [0 rows x 80 columns]

# %%
df['PoolQC'].unique()
# Out:
# array([nan, 'Ex', 'Fa', 'Gd'], dtype=object)

# %%
# 12 Sort the the value of LandContour in descending order then the values of utilities in ascending order  
df.sort_values(by = ['LandContour', 'Utilities'], ascending=[False, True])
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1377          30       RL         52.0     6292   Pave   NaN      Reg
# 1397          20       RL          NaN    57200   Pave   NaN      IR1
# 1415          50       RL         64.0    13053   Pave  Pave      Reg
# 1428          50       RL         60.0    10930   Pave  Grvl      Reg
# 1441          70       RL         79.0    11526   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                    ...
# ...

# %%
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %%
filt = df[df["PoolQC"]=="MnPrv"]
df2 = df.drop(index = filt.index)
df2
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                    ...
# ...

# %% [markdown]
# Research neighborhood quality and amenities

# %%
df.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
new_df = df.drop(columns = ['Fence', 'LotConfig', 'LandSlope', 'Alley', 'Fireplaces', 'FireplaceQu','GarageYrBlt', 'GarageCars', 'GarageArea','GarageFinish','GarageQual', 'GarageCond', 'Condition1', 'Condition2', 'PoolArea', 'LotShape', 'WoodDeckSF','LandContour', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolQC', 'MiscFeature', 'MiscVal', 'MSSubClass', 'MSZoning', 'LotFrontage'])
new_df
# Out:
#       LotArea Street Utilities Neighborhood BldgType HouseStyle  OverallQual  \
# Id
# 1        8450   Pave    AllPub      CollgCr     1Fam     2Story            7
# 2        9600   Pave    AllPub      Veenker     1Fam     1Story            6
# 3       11250   Pave    AllPub      CollgCr     1Fam     2Story            7
# 4        9550   Pave    AllPub      Crawfor     1Fam     2Story            7
# 5       14260   Pave    AllPub      NoRidge     1Fam     2Story            8
# ...       ...    ...       ...          ...      ...        ...          ...
# 1456     7917   Pave    AllPub      Gilbert     1Fam     2Story            6
# 1457    13175   Pave    AllPub       NWAmes     1Fam     1Story            6
# 1458     9042   Pave    AllPub      Crawfor     1Fam     2Story            7
# 1459     9717   Pave    AllPub        NAmes     1Fam     1Story            5
# 1460     9937   Pave    AllPub      Edwards     1Fam     1Story            5
#
# ...

# %%
filt_1 = new_df[new_df['OverallCond'] >= 5]

# %%
hdf =df[["LotArea", "YearBuilt", "OverallQual", "1stFlrSF", "2ndFlrSF", "SalePrice"]]

# %%
corr=hdf.corr()
corr.style.background_gradient(cmap='gray')
# Out:
# <style type="text/css">
# #T_82f84_row0_col0, #T_82f84_row1_col1, #T_82f84_row2_col2, #T_82f84_row3_col3, #T_82f84_row4_col4, #T_82f84_row5_col5 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_82f84_row0_col1 {
#   background-color: #010101;
#   color: #f1f1f1;
# }
# #T_82f84_row0_col2, #T_82f84_row0_col5, #T_82f84_row1_col0, #T_82f84_row3_col4, #T_82f84_row4_col1, #T_82f84_row4_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_82f84_row0_col3, #T_82f84_row2_col4, #T_82f84_row3_col2 {
#   background-color: #6a6a6a;
#   color: #f1f1f1;
# }
# #T_82f84_row0_col4 {
#   background-color: #353535;
#   color: #f1f1f1;
# }
# #T_82f84_row1_col2 {
#   background-color: #858585;
#   color: #f1f1f1;
# }
# #T_82f84_row1_col3 {
#   background-color: #676767;
#   color: #f1f1f1;
# }
# #T_82f84_row1_col4 {
#   background-color: #2d2d2d;
#   color: #f1f1f1;
# }
# #T_82f84_row1_col5 {
#   background-color: #5a5a5a;
#   color: #f1f1f1;
# }
# #T_82f84_row2_col0 {
# ...

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X =hdf[["LotArea", "YearBuilt", "OverallQual", "1stFlrSF", "2ndFlrSF"]]

# %%
y = hdf[["SalePrice"]]

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
model.fit(X.values, y)
# Out:
# LinearRegression()

# %%
model.predict([[8450, 2003, 7,856, 854]])
# Out:
# array([[215742.09360783]])

# %%
model.score(X.values,y)
# Out:
# 0.7639947415631084

# %% [markdown]
# Normalization and Standardization

# %%
X_norm = X.copy()

# %%
y_norm = y.copy()

# %%
col: str = 'LotArea'
X_norm[col] = (hdf[col] - hdf[col].min()) / (hdf[col].max() - hdf[col].min())
X_norm
# Out:
#        LotArea  YearBuilt  OverallQual  1stFlrSF  2ndFlrSF
# Id
# 1     0.033420       2003            7       856       854
# 2     0.038795       1976            6      1262         0
# 3     0.046507       2001            7       920       866
# 4     0.038561       1915            7       961       756
# 5     0.060576       2000            8      1145      1053
# ...        ...        ...          ...       ...       ...
# 1456  0.030929       1999            6       953       694
# 1457  0.055505       1978            6      2073         0
# 1458  0.036187       1941            7      1188      1152
# 1459  0.039342       1950            5      1078         0
# 1460  0.040370       1965            5      1256         0
#
# [1460 rows x 5 columns]

# %%
for col in X_norm:
    X_norm[col] = (hdf[col] - hdf[col].min()) / (hdf[col].max() - hdf[col].min())
X_norm
# Out:
#        LotArea  YearBuilt  OverallQual  1stFlrSF  2ndFlrSF
# Id
# 1     0.033420   0.949275     0.666667  0.119780  0.413559
# 2     0.038795   0.753623     0.555556  0.212942  0.000000
# 3     0.046507   0.934783     0.666667  0.134465  0.419370
# 4     0.038561   0.311594     0.666667  0.143873  0.366102
# 5     0.060576   0.927536     0.777778  0.186095  0.509927
# ...        ...        ...          ...       ...       ...
# 1456  0.030929   0.920290     0.555556  0.142038  0.336077
# 1457  0.055505   0.768116     0.555556  0.399036  0.000000
# 1458  0.036187   0.500000     0.666667  0.195961  0.557869
# 1459  0.039342   0.565217     0.444444  0.170721  0.000000
# 1460  0.040370   0.673913     0.444444  0.211565  0.000000
#
# [1460 rows x 5 columns]

# %%
model.fit(X_norm,y_norm)
# Out:
# LinearRegression()

# %% [markdown]
# Scalling attributes with Standardization

# %%
df_std= hdf.copy()
df_std
# Out:
#       LotArea  YearBuilt  OverallQual  1stFlrSF  2ndFlrSF  SalePrice
# Id
# 1        8450       2003            7       856       854     208500
# 2        9600       1976            6      1262         0     181500
# 3       11250       2001            7       920       866     223500
# 4        9550       1915            7       961       756     140000
# 5       14260       2000            8      1145      1053     250000
# ...       ...        ...          ...       ...       ...        ...
# 1456     7917       1999            6       953       694     175000
# 1457    13175       1978            6      2073         0     210000
# 1458     9042       1941            7      1188      1152     266500
# 1459     9717       1950            5      1078         0     142125
# 1460     9937       1965            5      1256         0     147500
#
# [1460 rows x 6 columns]

# %%
X_std = df_std[["LotArea", "YearBuilt", "OverallQual", "1stFlrSF", "2ndFlrSF"]]

# %%
y_std = df_std[["SalePrice"]]

# %%
col: str = 'LotArea'
X_std[col] = (df_std[col] - df_std[col].mean()) / df_std[col].std()
# Out:
# c:\Users\ALFY\anaconda3\envs\pylearn\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for col in X_std:
    X_std[col] = (df_std[col] - df_std[col].mean()) / df_std[col].std()
X_std
# Out:
# c:\Users\ALFY\anaconda3\envs\pylearn\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        LotArea  YearBuilt  OverallQual  1stFlrSF  2ndFlrSF
# Id
# 1    -0.207071   1.050634     0.651256 -0.793162  1.161454
# 2    -0.091855   0.156680    -0.071812  0.257052 -0.794891
# 3     0.073455   0.984415     0.651256 -0.627611  1.188943
# 4    -0.096864  -1.862993     0.651256 -0.521555  0.936955
# 5     0.375020   0.951306     1.374324 -0.045596  1.617323
# ...        ...        ...          ...       ...       ...
# 1456 -0.260471   0.918196    -0.071812 -0.542249  0.794925
# 1457  0.266316   0.222899    -0.071812  2.354894 -0.794891
# 1458 -0.147760  -1.002149     0.651256  0.065634  1.844112
# ...
